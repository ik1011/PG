# %% [markdown]
# ##**Model Script**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/yolov8')

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.228 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %%
from ultralytics import YOLO
model1=YOLO('/content/gdrive/MyDrive/yolov8/runs/detect/SIH_model/weights/best.pt')

# %%
model1.predict('/content/gdrive/MyDrive/yolov8/inference/thrash/labels.jpg',save=True,conf=0.45)
# Out:
# image 1/1 /content/gdrive/MyDrive/yolov8/inference/thrash/labels.jpg: 480x640 (no detections), 112.8ms
# Speed: 5.6ms preprocess, 112.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict19
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Litter', 1: 'Litter'}
#  orig_img: array([[[ 47,  45,  65],
#          [ 59,  57,  77],
#          [ 58,  56,  76],
#          ...,
#          [ 39,  64,  90],
#          [ 51,  74, 100],
#          [ 55,  78, 104]],
#
#         [[ 46,  44,  63],
#          [ 56,  56,  74],
#          [ 46,  44,  63],
#          ...,
#          [ 35,  60,  86],
#          [ 39,  61,  89],
#          [ 49,  72,  98]],
#
#         [[ 65,  67,  78],
#          [ 49,  53,  64],
#          [ 59,  61,  72],
#          ...,
#          [ 39,  63,  91],
#          [ 43,  64,  95],
#          [ 44,  66,  94]],
# ...

# %%
org_pth='/content/gdrive/MyDrive/yolov8/'
last_pred_pth='runs/detect/predict9'
folder_pth=os.path.join(org_pth,'runs/detect/predict9')
i=os.listdir(folder_pth)[-1]
img_pth=os.path.join(folder_pth,i)
img_pth
# Out:
# '/content/gdrive/MyDrive/yolov8/runs/detect/predict9/cdn4.premiumread.jpg'

# %%
# Function to show Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def showImage(path):
  img = mpimg.imread(path)
  plt.figure(figsize=(20,20))
  plt.axis("off")
  plt.imshow(img)
  plt.show()

def showImagesOnFolder(path):
  for file in os.listdir(path):
    if (file.endswith(".png") or file.endswith(".jpg")):
      image_path = os.path.join(path, file)
      showImage(image_path)

# %%
folder_pth='/content/gdrive/MyDrive/yolov8'
final_pth=os.path.join(folder_pth,'runs/detect/predict9')

# %%
showImagesOnFolder(final_pth)
