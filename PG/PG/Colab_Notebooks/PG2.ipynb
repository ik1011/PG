# %% [markdown]
# ##**Model Script**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/yolov8')

# %%
# Install YOLOv8
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.9/78.2 GB disk)

# %%
from ultralytics import YOLO
model1=YOLO('/content/gdrive/MyDrive/yolov8/runs/detect/SIH_model/weights/vandalism.pt')
model2

# %%
model1.predict('/content/gdrive/MyDrive/yolov8/inference/HSV/cdn4.premiumread.jpg',save=True,conf=0.5)
# Out:
# image 1/1 /content/gdrive/MyDrive/yolov8/inference/HSV/cdn4.premiumread.jpg: 448x640 5 Vandalisms, 115.3ms
# Speed: 14.5ms preprocess, 115.3ms inference, 40.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict9
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Vandalism'}
#  orig_img: array([[[194, 184, 177],
#          [195, 185, 178],
#          [195, 185, 178],
#          ...,
#          [100, 109, 112],
#          [104, 108, 113],
#          [ 89,  93,  98]],
#
#         [[196, 186, 179],
#          [198, 188, 181],
#          [196, 186, 179],
#          ...,
#          [ 68,  75,  78],
#          [ 69,  73,  78],
#          [ 57,  61,  66]],
#
#         [[196, 186, 179],
#          [196, 186, 179],
#          [195, 185, 178],
#          ...,
#          [  0,   3,   7],
#          [  0,   2,   6],
#          [  0,   1,   5]],
#
#         ...,
#
#         [[194, 190, 185],
#          [198, 194, 189],
#          [202, 198, 193],
#          ...,
#          [101, 114, 116],
#          [101, 112, 116],
#          [110, 121, 125]],
#
#         [[194, 190, 185],
#          [198, 194, 189],
#          [202, 198, 193],
#          ...,
#          [101, 114, 116],
#          [101, 114, 116],
#          [110, 123, 125]],
#
#         [[193, 189, 184],
#          [197, 193, 188],
#          [198, 194, 189],
#          ...,
#          [ 84,  97,  99],
#          [ 85,  98, 100],
#          [ 95, 108, 110]]], dtype=uint8)
#  orig_shape: (662, 1000)
#  path: '/content/gdrive/MyDrive/yolov8/inference/HSV/cdn4.premiumread.jpg'
#  probs: None
#  save_dir: 'runs/detect/predict9'
#  speed: {'preprocess': 14.549970626831055, 'inference': 115.33260345458984, 'postprocess': 40.60935974121094}]

# %%
org_pth='/content/gdrive/MyDrive/yolov8/'
last_pred_pth='runs/detect/predict9'
folder_pth=os.path.join(org_pth,'runs/detect/predict9')
i=os.listdir(folder_pth)[-1]
img_pth=os.path.join(folder_pth,i)
img_pth
# Out:
# '/content/gdrive/MyDrive/yolov8/runs/detect/predict9/cdn4.premiumread.jpg'

# %%
model2.predict('/content/gdrive/MyDrive/yolov8/inference/HSV/COS2 (1).mp4',save=True,conf=0.5,boxes=False,hide_conf=True,hide_labels=True)

# %%
# Function to show Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def showImage(path):
  img = mpimg.imread(path)
  plt.figure(figsize=(20,20))
  plt.axis("off")
  plt.imshow(img)
  plt.show()

def showImagesOnFolder(path):
  for file in os.listdir(path):
    if (file.endswith(".png") or file.endswith(".jpg")):
      image_path = os.path.join(path, file)
      showImage(image_path)

# %%
folder_pth='/content/gdrive/MyDrive/yolov8'
final_pth=os.path.join(folder_pth,'runs/detect/predict9')

# %%
showImagesOnFolder(final_pth)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
